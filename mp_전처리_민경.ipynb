# %% [markdown]
# <a href="https://colab.research.google.com/github/chacha715/ESAA/blob/main/mp_%EC%A0%84%EC%B2%98%EB%A6%AC_%EB%AF%BC%EA%B2%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6. director: 감독 이름
#
# *   감독별 관객 수 분포 조사 -> 왜곡 정도 완화 -> 중앙값으로 rank 매기기
# *   질문) 감독이 낸 영화 수를 고려해야 하는가?

# %%
director_num = train.groupby('director')['box_off_num'].sum().sort_values(ascending=False)
df6 = pd.DataFrame(director_num)
df6["director"]= df6.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
ax = plt.subplots()
ax = sns.barplot(x='box_off_num', y='director',data = df6)

# %%
#위의 그래프가 왜곡되어있으므로 log1p 변환을 통해 왜곡 정도 향상
director_num = train.groupby('director')['box_off_num'].sum().sort_values(ascending=False)
df6 = pd.DataFrame(director_num)
df6["director"]= df6.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
df6["box_off_num"]=np.log1p(df6["box_off_num"])
ax = plt.subplots()
ax = sns.barplot(x='box_off_num', y='director',data = df6)

# %%
df6.drop(['director'], axis=1, inplace=True)
tr_dr_rank = df6.groupby('director').box_off_num.median().reset_index(name = 'dr_rank').sort_values(by = 'dr_rank')
tr_dr_rank
# Out:
#     director    dr_rank
# 125      노성수   0.693147
# 85       김정호   1.098612
# 10       고구마   2.197225
# 289      이세일   2.397895
# 411      진광교   3.610918
# ..       ...        ...
# 332      이환경  16.406809
# 428      추창민  16.452638
# 264      윤제균  16.473163
# 285      이석훈  16.614371
# 416      최동훈  17.061632
#
# [472 rows x 2 columns]

# %%
tr_dr_rank['dr_rank'] = [i + 1 for i in range(tr_dr_rank.shape[0])]

# %%
tr_dr_rank
# Out:
#     director  dr_rank
# 125      노성수        1
# 85       김정호        2
# 10       고구마        3
# 289      이세일        4
# 411      진광교        5
# ..       ...      ...
# 332      이환경      468
# 428      추창민      469
# 264      윤제균      470
# 285      이석훈      471
# 416      최동훈      472
#
# [472 rows x 2 columns]

# %% [markdown]
# 7. dir_prev_bfnum : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
#
# *   330개 Null

# %%
director_num = train.groupby('director')['dir_prev_bfnum'].sum().sort_values(ascending=False)
df7 = pd.DataFrame(director_num)
df7["director"]= df7.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
ax = plt.subplots()
ax = sns.barplot(x='dir_prev_bfnum', y='director',data = df7)

# %%
#위의 그래프가 왜곡되어있으므로 log1p 변환을 통해 왜곡 정도 향상
director_num = train.groupby('director')['dir_prev_bfnum'].sum().sort_values(ascending=False)
df7 = pd.DataFrame(director_num)
df7["director"]= df7.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
df7['dir_prev_bfnum']=np.log1p(df7['dir_prev_bfnum']) 
ax = plt.subplots()
ax = sns.barplot(x='dir_prev_bfnum', y='director',data = df7)

# %%
df7.drop(['director'], axis=1, inplace=True)
tr_drbf_rank = df7.groupby('director').dir_prev_bfnum.median().reset_index(name = 'drbf_rank').sort_values(by = 'drbf_rank')
tr_drbf_rank
# Out:
#        director  drbf_rank
# 0    New Pistol   0.000000
# 277         이대희   0.000000
# 275        이길보라   0.000000
# 273         이규만   0.000000
# 272         이광호   0.000000
# ..          ...        ...
# 62          김상진  15.871628
# 232         심형래  15.876721
# 53          김민석  15.990449
# 5           강형철  16.591959
# 10          고구마  16.684279
#
# [472 rows x 2 columns]

# %%
tr_drbf_rank['drbf_rank'] = [i + 1 for i in range(tr_drbf_rank.shape[0])]
tr_drbf_rank
# Out:
#        director  drbf_rank
# 0    New Pistol          1
# 277         이대희          2
# 275        이길보라          3
# 273         이규만          4
# 272         이광호          5
# ..          ...        ...
# 62          김상진        468
# 232         심형래        469
# 53          김민석        470
# 5           강형철        471
# 10          고구마        472
#
# [472 rows x 2 columns]

# %% [markdown]
# 8. dir_prev_num : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)

# %%
director_num = train.groupby('director')['dir_prev_num'].sum().sort_values(ascending=False)
df8 = pd.DataFrame(director_num)
df8["director"]= df8.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
ax = plt.subplots()
ax = sns.barplot(x='dir_prev_num', y='director',data = df8)

# %%
#위의 그래프가 왜곡되어있으므로 log1p 변환을 통해 왜곡 정도 향상
director_num = train.groupby('director')['dir_prev_num'].sum().sort_values(ascending=False)
df8 = pd.DataFrame(director_num)
df8["director"]= df8.index #director 열 생성
plt.rcParams['figure.figsize'] = [10,10] 
df8['dir_prev_num']=np.log1p(df8['dir_prev_num']) 
ax = plt.subplots()
ax = sns.barplot(x='dir_prev_num', y='director',data = df8)

# %%
df8.drop(['director'], axis=1, inplace=True)
tr_drp_rank = df8.groupby('director').dir_prev_num.median().reset_index(name = 'drp_rank').sort_values(by = 'drp_rank')
tr_drp_rank
# Out:
#        director  drp_rank
# 0    New Pistol  0.000000
# 277         이대희  0.000000
# 275        이길보라  0.000000
# 273         이규만  0.000000
# 272         이광호  0.000000
# ..          ...       ...
# 258          유하  2.079442
# 324         이해영  2.197225
# 118          김휘  2.197225
# 62          김상진  2.197225
# 111         김현석  2.302585
#
# [472 rows x 2 columns]

# %%
tr_drp_rank['drp_rank'] = [i + 1 for i in range(tr_drp_rank.shape[0])]
tr_drp_rank
# Out:
#        director  drp_rank
# 0    New Pistol         1
# 277         이대희         2
# 275        이길보라         3
# 273         이규만         4
# 272         이광호         5
# ..          ...       ...
# 258          유하       468
# 324         이해영       469
# 118          김휘       470
# 62          김상진       471
# 111         김현석       472
#
# [472 rows x 2 columns]

# %% [markdown]
# 6,7,8. director와 box_off_num, dir_prev_bfnum, dir_prev_num을 이용해 director의 rank 생성
#
# *   의문1) 세 가지를 평균 등으로 합친 변수 만들어야 할지?
# *   의문2) dir_prev_bfnum, dir_prev_num에서는 이전 영화가 없어서인지 값이 0이었던 감독들도 순서대로 다른 값을 rank에 배정받았는데, 어떻게 처리해야할지
# *   (주의) log1p 변환하고 나면 이전으로 돌아가는 과정 필요하니 그래프 두 개씩 그릴때 순서대로 그리기. 아니면 두 개 한번에 그리거나
